# %%
using Interpolations
include("../test/visual.jl")
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink"
#      xmlns:gadfly="http://www.gadflyjl.org/ns"
#      version="1.2"
#      width="141.42mm" height="100mm" viewBox="0 0 141.42 100"
#      stroke="none"
#      fill="#000000"
#      stroke-width="0.3"
#      font-size="3.88"
#
#      id="fig-9635e66d7059479dbd9bd8ed21990eaf">
# <g class="plotroot xscalable yscalable" id="fig-9635e66d7059479dbd9bd8ed21990eaf-element-1">
#   <g font-size="3.88" font-family="'PT Sans','Helvetica Neue','Helvetica',sans-serif" fill="#564A55" stroke="none" id="fig-9635e66d7059479dbd9bd8ed21990eaf-element-2">
#     <text x="77.18" y="92" text-anchor="middle">x</text>
#   </g>
#   <g class="guide xlabels" font-size="2.82" font-family="'PT Sans Caption','Helvetica Neue','Helvetica',sans-serif" fill="#6C606B" id="fig-9635e66d7059479dbd9bd8ed21990eaf-element-3">
# ...
